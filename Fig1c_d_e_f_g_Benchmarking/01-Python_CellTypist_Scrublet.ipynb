# %%
import sys
import getopt
import shutil
import h5py
import re
import os
import numpy as np
import pandas as pd
import scanpy as sc
import celltypist
import gc
import anndata
from celltypist import models
import h5py
import scipy.sparse as scs
from multiprocessing import Pool
import scrublet

# %%
h5_list = ['sample1','sample2','sample3','sample4',
           'sample5','sample6','sample7','sample8',
           'sample9','sample10','sample11','sample12',
           'sample13','sample14','sample15','sample16']

# %%
in_dir = '../../reflex_data/EXP1936_GEX_Updated/'

# %%
for h5_in in h5_list:
    print(h5_in)

    h5_path = in_dir + '/outs/per_sample_outs/' + h5_in + '/sample_filtered_feature_bc_matrix.h5'

    # Perform Scrublet & celltypist
    adata = sc.read_10x_h5(h5_path)
    sc.pp.normalize_total(adata, target_sum=1e4)
    sc.pp.log1p(adata)
    predictions_l1 = celltypist.annotate(adata, model='/home/workspace/celltypist_dev/models/model_AIFI_PBMC_L1_ovr.pkl')
    predictions_l2 = celltypist.annotate(adata, model='/home/workspace/celltypist_dev/models/model_AIFI_PBMC_L2_ovr.pkl')
    predictions_l3 = celltypist.annotate(adata, model='/home/workspace/celltypist_dev/models/model_AIFI_PBMC_L3_multinomial.pkl')

    df = pd.DataFrame(predictions_l1.predicted_labels)
    df.columns = ['L1']
    df2 = pd.DataFrame(predictions_l2.predicted_labels)
    df2.columns = ['L2']
    df3 = pd.DataFrame(predictions_l3.predicted_labels)
    df3.columns = ['L3']

    df_merge = df.merge(df2, left_index=True, right_index=True)
    df_merge2 = df_merge.merge(df3, left_index=True, right_index=True)
    df_merge2.to_csv(path_or_buf = 'reflex_celltypist_scrublet/' + h5_in+'_celltypes.csv')
    
    
    adata.shape
    scrub = scrublet.Scrublet(adata.X)
    doublet_scores, predicted_doublets = scrub.scrub_doublets(verbose = False)

    df = pd.DataFrame(doublet_scores)
    df.columns = ['Doublet_Score']
    df2 = pd.DataFrame(predicted_doublets)
    df2.columns = ['Predicted_Doublet']

    df_merge = df.merge(df2, left_index=True, right_index=True)
    df_merge.to_csv(path_or_buf = 'reflex_celltypist_scrublet/' + h5_in +'_doublets.csv')
# Out:
# sample1
# 🔬 Input data has 10543 cells and 18129 genes
# 🔗 Matching reference genes in the model
# 🧬 889 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🔬 Input data has 10543 cells and 18129 genes
# 🔗 Matching reference genes in the model
# 🧬 1630 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🔬 Input data has 10543 cells and 18129 genes
# 🔗 Matching reference genes in the model
# 🧬 2165 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# sample2
# 🔬 Input data has 10499 cells and 18129 genes
# 🔗 Matching reference genes in the model
# 🧬 889 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🔬 Input data has 10499 cells and 18129 genes
# 🔗 Matching reference genes in the model
# 🧬 1630 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🔬 Input data has 10499 cells and 18129 genes
# 🔗 Matching reference genes in the model
# 🧬 2165 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# sample3
# 🔬 Input data has 9578 cells and 18129 genes
# 🔗 Matching reference genes in the model
# 🧬 889 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🔬 Input data has 9578 cells and 18129 genes
# 🔗 Matching reference genes in the model
# 🧬 1630 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🔬 Input data has 9578 cells and 18129 genes
# 🔗 Matching reference genes in the model
# 🧬 2165 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# sample4
# 🔬 Input data has 10790 cells and 18129 genes
# 🔗 Matching reference genes in the model
# 🧬 889 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🔬 Input data has 10790 cells and 18129 genes
# 🔗 Matching reference genes in the model
# 🧬 1630 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🔬 Input data has 10790 cells and 18129 genes
# 🔗 Matching reference genes in the model
# 🧬 2165 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# sample5
# 🔬 Input data has 9263 cells and 18129 genes
# 🔗 Matching reference genes in the model
# 🧬 889 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🔬 Input data has 9263 cells and 18129 genes
# 🔗 Matching reference genes in the model
# 🧬 1630 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🔬 Input data has 9263 cells and 18129 genes
# 🔗 Matching reference genes in the model
# 🧬 2165 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# sample6
# 🔬 Input data has 10056 cells and 18129 genes
# 🔗 Matching reference genes in the model
# 🧬 889 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🔬 Input data has 10056 cells and 18129 genes
# 🔗 Matching reference genes in the model
# 🧬 1630 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🔬 Input data has 10056 cells and 18129 genes
# 🔗 Matching reference genes in the model
# 🧬 2165 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# sample7
# 🔬 Input data has 9101 cells and 18129 genes
# 🔗 Matching reference genes in the model
# 🧬 889 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🔬 Input data has 9101 cells and 18129 genes
# 🔗 Matching reference genes in the model
# 🧬 1630 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🔬 Input data has 9101 cells and 18129 genes
# 🔗 Matching reference genes in the model
# 🧬 2165 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# sample8
# 🔬 Input data has 9592 cells and 18129 genes
# 🔗 Matching reference genes in the model
# 🧬 889 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🔬 Input data has 9592 cells and 18129 genes
# 🔗 Matching reference genes in the model
# 🧬 1630 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🔬 Input data has 9592 cells and 18129 genes
# 🔗 Matching reference genes in the model
# 🧬 2165 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# sample9
# 🔬 Input data has 9731 cells and 18129 genes
# 🔗 Matching reference genes in the model
# 🧬 889 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🔬 Input data has 9731 cells and 18129 genes
# 🔗 Matching reference genes in the model
# 🧬 1630 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🔬 Input data has 9731 cells and 18129 genes
# 🔗 Matching reference genes in the model
# 🧬 2165 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# sample10
# 🔬 Input data has 9905 cells and 18129 genes
# 🔗 Matching reference genes in the model
# 🧬 889 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🔬 Input data has 9905 cells and 18129 genes
# 🔗 Matching reference genes in the model
# 🧬 1630 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🔬 Input data has 9905 cells and 18129 genes
# 🔗 Matching reference genes in the model
# 🧬 2165 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# sample11
# 🔬 Input data has 8967 cells and 18129 genes
# 🔗 Matching reference genes in the model
# 🧬 889 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🔬 Input data has 8967 cells and 18129 genes
# 🔗 Matching reference genes in the model
# 🧬 1630 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🔬 Input data has 8967 cells and 18129 genes
# 🔗 Matching reference genes in the model
# 🧬 2165 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# sample12
# 🔬 Input data has 9527 cells and 18129 genes
# 🔗 Matching reference genes in the model
# 🧬 889 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🔬 Input data has 9527 cells and 18129 genes
# 🔗 Matching reference genes in the model
# 🧬 1630 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🔬 Input data has 9527 cells and 18129 genes
# 🔗 Matching reference genes in the model
# 🧬 2165 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# sample13
# 🔬 Input data has 9805 cells and 18129 genes
# 🔗 Matching reference genes in the model
# 🧬 889 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🔬 Input data has 9805 cells and 18129 genes
# 🔗 Matching reference genes in the model
# 🧬 1630 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🔬 Input data has 9805 cells and 18129 genes
# 🔗 Matching reference genes in the model
# 🧬 2165 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# sample14
# 🔬 Input data has 9259 cells and 18129 genes
# 🔗 Matching reference genes in the model
# 🧬 889 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🔬 Input data has 9259 cells and 18129 genes
# 🔗 Matching reference genes in the model
# 🧬 1630 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🔬 Input data has 9259 cells and 18129 genes
# 🔗 Matching reference genes in the model
# 🧬 2165 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# sample15
# 🔬 Input data has 9301 cells and 18129 genes
# 🔗 Matching reference genes in the model
# 🧬 889 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🔬 Input data has 9301 cells and 18129 genes
# 🔗 Matching reference genes in the model
# 🧬 1630 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🔬 Input data has 9301 cells and 18129 genes
# 🔗 Matching reference genes in the model
# 🧬 2165 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# sample16
# 🔬 Input data has 9232 cells and 18129 genes
# 🔗 Matching reference genes in the model
# 🧬 889 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🔬 Input data has 9232 cells and 18129 genes
# 🔗 Matching reference genes in the model
# 🧬 1630 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🔬 Input data has 9232 cells and 18129 genes
# 🔗 Matching reference genes in the model
# 🧬 2165 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
