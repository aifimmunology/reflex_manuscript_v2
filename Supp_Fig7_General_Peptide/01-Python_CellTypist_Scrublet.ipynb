# %%
import sys
import getopt
import shutil
import h5py
import re
import os
import numpy as np
import pandas as pd
import scanpy as sc
import celltypist
import gc
import anndata
from celltypist import models
import h5py
import scipy.sparse as scs
from multiprocessing import Pool
import scrublet

# %%
h5_list = ['D0_2164',
'D0_3446',
'D10_2164_CEFSX',
'D10_2164_EBV',
'D10_2164_null',
'D10_3446_CEFSX',
'D10_3446_EBV',
'D10_3446_null']

# %%
in_dir = '../../reflex_data/VST4_GEX/'

# %%
for h5_in in h5_list:
    print(h5_in)

    h5_path = in_dir + 'outs/per_sample_outs/' + h5_in + '/sample_filtered_feature_bc_matrix.h5'

    # Perform Scrublet & celltypist
    adata = sc.read_10x_h5(h5_path)
    sc.pp.normalize_total(adata, target_sum=1e4)
    sc.pp.log1p(adata)
    predictions_l1 = celltypist.annotate(adata, model='/home/workspace/celltypist_dev/models/model_AIFI_PBMC_L1_ovr.pkl')
    predictions_l2 = celltypist.annotate(adata, model='/home/workspace/celltypist_dev/models/model_AIFI_PBMC_L2_ovr.pkl')
    predictions_l3 = celltypist.annotate(adata, model='/home/workspace/celltypist_dev/models/model_AIFI_PBMC_L3_multinomial.pkl')

    df = pd.DataFrame(predictions_l1.predicted_labels)
    df.columns = ['L1']
    df2 = pd.DataFrame(predictions_l2.predicted_labels)
    df2.columns = ['L2']
    df3 = pd.DataFrame(predictions_l3.predicted_labels)
    df3.columns = ['L3']

    df_merge = df.merge(df2, left_index=True, right_index=True)
    df_merge2 = df_merge.merge(df3, left_index=True, right_index=True)
    df_merge2.to_csv(path_or_buf = 'scrublet_celltypist/' + h5_in + '_celltypes.csv')
    
    
    adata.shape
    scrub = scrublet.Scrublet(adata.X)
    doublet_scores, predicted_doublets = scrub.scrub_doublets(verbose = False)

    df = pd.DataFrame(doublet_scores)
    df.columns = ['Doublet_Score']
    df2 = pd.DataFrame(predicted_doublets)
    df2.columns = ['Predicted_Doublet']

    df_merge = df.merge(df2, left_index=True, right_index=True)
    df_merge.to_csv(path_or_buf = 'scrublet_celltypist/' + h5_in+'_doublets.csv')
# Out:
# D0_2164
# 🔬 Input data has 22725 cells and 18129 genes
# 🔗 Matching reference genes in the model
# 🧬 889 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🔬 Input data has 22725 cells and 18129 genes
# 🔗 Matching reference genes in the model
# 🧬 1630 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🔬 Input data has 22725 cells and 18129 genes
# 🔗 Matching reference genes in the model
# 🧬 2165 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# D0_3446
# 🔬 Input data has 25423 cells and 18129 genes
# 🔗 Matching reference genes in the model
# 🧬 889 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🔬 Input data has 25423 cells and 18129 genes
# 🔗 Matching reference genes in the model
# 🧬 1630 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🔬 Input data has 25423 cells and 18129 genes
# 🔗 Matching reference genes in the model
# 🧬 2165 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# D10_2164_CEFSX
# 🔬 Input data has 15012 cells and 18129 genes
# 🔗 Matching reference genes in the model
# 🧬 889 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🔬 Input data has 15012 cells and 18129 genes
# 🔗 Matching reference genes in the model
# 🧬 1630 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🔬 Input data has 15012 cells and 18129 genes
# 🔗 Matching reference genes in the model
# 🧬 2165 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# D10_2164_EBV
# 🔬 Input data has 16333 cells and 18129 genes
# 🔗 Matching reference genes in the model
# 🧬 889 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🔬 Input data has 16333 cells and 18129 genes
# 🔗 Matching reference genes in the model
# 🧬 1630 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🔬 Input data has 16333 cells and 18129 genes
# 🔗 Matching reference genes in the model
# 🧬 2165 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# D10_2164_null
# 🔬 Input data has 20690 cells and 18129 genes
# 🔗 Matching reference genes in the model
# 🧬 889 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🔬 Input data has 20690 cells and 18129 genes
# 🔗 Matching reference genes in the model
# 🧬 1630 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🔬 Input data has 20690 cells and 18129 genes
# 🔗 Matching reference genes in the model
# 🧬 2165 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# D10_3446_CEFSX
# 🔬 Input data has 15893 cells and 18129 genes
# 🔗 Matching reference genes in the model
# 🧬 889 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🔬 Input data has 15893 cells and 18129 genes
# 🔗 Matching reference genes in the model
# 🧬 1630 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🔬 Input data has 15893 cells and 18129 genes
# 🔗 Matching reference genes in the model
# 🧬 2165 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# D10_3446_EBV
# 🔬 Input data has 14287 cells and 18129 genes
# 🔗 Matching reference genes in the model
# 🧬 889 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🔬 Input data has 14287 cells and 18129 genes
# 🔗 Matching reference genes in the model
# 🧬 1630 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🔬 Input data has 14287 cells and 18129 genes
# 🔗 Matching reference genes in the model
# 🧬 2165 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# D10_3446_null
# 🔬 Input data has 15911 cells and 18129 genes
# 🔗 Matching reference genes in the model
# 🧬 889 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🔬 Input data has 15911 cells and 18129 genes
# 🔗 Matching reference genes in the model
# 🧬 1630 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
# 🔬 Input data has 15911 cells and 18129 genes
# 🔗 Matching reference genes in the model
# 🧬 2165 features used for prediction
# ⚖️ Scaling input data
# 🖋️ Predicting labels
# ✅ Prediction done!
